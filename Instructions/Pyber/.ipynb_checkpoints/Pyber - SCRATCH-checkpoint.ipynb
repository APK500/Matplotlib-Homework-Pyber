# %%
# Importing the dependancies:

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
# store the filepath(s) into variables  (for each of the two csv files, city_data & ride_data):

city_data_file = "raw_data/city_data.csv"
ride_data_file = "raw_data/ride_data.csv"

# %%
# Pull in & Read our CSV data files with pandas

#Check the data for city_data & create a dataframe (header):
city_data_df = pd.read_csv(city_data_file)

city_data_df
# Out:
#                      city  driver_count      type
# 0              Kelseyland            63     Urban
# 1              Nguyenbury             8     Urban
# 2            East Douglas            12     Urban
# 3           West Dawnfurt            34     Urban
# 4          Rodriguezburgh            52     Urban
# 5       South Josephville             4     Urban
# 6        West Sydneyhaven            70     Urban
# 7             Travisville            37     Urban
# 8             Torresshire            70     Urban
# 9               Lisaville            66     Urban
# 10              Mooreview            34     Urban
# 11             Smithhaven            67     Urban
# 12            Carrollfort            55     Urban
# 13        Port Josephfurt            28     Urban
# 14       Lake Jeffreyland            15     Urban
# 15            South Louis            12     Urban
# 16             West Peter            61     Urban
# 17        Kimberlychester            13     Urban
# ...

# %%
# Pull in & Read our CSV data files with pandas

#Check the data for ride_data & create a dataframe (header):
ride_data_df = pd.read_csv(ride_data_file)
ride_data_df
# Out:
#                       city                 date   fare        ride_id
# 0                 Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1                South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2              Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3              Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4               Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673
# 5              New Jeffrey  2016-02-22 18:36:25  36.01  9757888452346
# 6            Port Johnstad  2016-06-07 02:39:58  17.15  4352278259335
# 7                Jacobfort  2016-09-20 20:58:37  22.98  1500221409082
# 8              Travisville  2016-01-15 17:32:02  27.39   850152768361
# 9               Sandymouth  2016-11-16 07:27:00  21.61  2389035050524
# 10         New Andreamouth  2016-04-11 07:20:48   7.72  9992929847990
# 11           New Christine  2016-09-13 15:06:42  24.89  7918411468537
# ...

# %%
merge_table = pd.merge(city_data_df, ride_data_df, on="city", how="outer")
merge_table
# Out:
#                 city  driver_count   type                 date   fare  \
# 0         Kelseyland            63  Urban  2016-08-19 04:27:52   5.51
# 1         Kelseyland            63  Urban  2016-04-17 06:59:50   5.54
# 2         Kelseyland            63  Urban  2016-05-04 15:06:07  30.54
# 3         Kelseyland            63  Urban  2016-01-25 20:44:56  12.08
# 4         Kelseyland            63  Urban  2016-08-09 18:19:47  17.91
# 5         Kelseyland            63  Urban  2016-10-24 15:15:46  33.56
# 6         Kelseyland            63  Urban  2016-06-06 13:54:23  20.81
# 7         Kelseyland            63  Urban  2016-08-10 07:02:40  44.53
# 8         Kelseyland            63  Urban  2016-07-05 17:37:13  29.02
# 9         Kelseyland            63  Urban  2016-04-25 02:18:31  20.05
# 10        Kelseyland            63  Urban  2016-01-25 08:47:09   9.29
# 11        Kelseyland            63  Urban  2016-11-10 01:57:14  20.58
# ...

# %%
merge_table_df.mean()
# Out:
# driver_count    3.114167e+01
# fare            2.686710e+01
# ride_id         4.856048e+12
# dtype: float64

# %%
# Set the 'city' as our index
merge_table_df = merge_table.set_index('city')
merge_table_df
# Out:
#                 driver_count   type                 date   fare        ride_id
# city
# Kelseyland                63  Urban  2016-08-19 04:27:52   5.51  6246006544795
# Kelseyland                63  Urban  2016-04-17 06:59:50   5.54  7466473222333
# Kelseyland                63  Urban  2016-05-04 15:06:07  30.54  2140501382736
# Kelseyland                63  Urban  2016-01-25 20:44:56  12.08  1896987891309
# Kelseyland                63  Urban  2016-08-09 18:19:47  17.91  8784212854829
# Kelseyland                63  Urban  2016-10-24 15:15:46  33.56  4797969661996
# Kelseyland                63  Urban  2016-06-06 13:54:23  20.81  9811478565448
# Kelseyland                63  Urban  2016-08-10 07:02:40  44.53  1563171128434
# Kelseyland                63  Urban  2016-07-05 17:37:13  29.02  6897992353955
# Kelseyland                63  Urban  2016-04-25 02:18:31  20.05  1148374505062
# Kelseyland                63  Urban  2016-01-25 08:47:09   9.29   213692794373
# ...

# %%
# Out:
# driver_count    3.114167e+01
# fare            2.686710e+01
# ride_id         4.856048e+12
# dtype: float64

# %%
#count the number of unique cities's entries in the data set:

count = merge_table_df["city"].value_counts()
count
# Out:
# Port James              64
# Swansonbury             34
# Port Johnstad           34
# South Louis             32
# Williamshire            31
# Arnoldview              31
# Alvarezhaven            31
# West Peter              31
# Jacobfort               31
# West Brandy             30
# Stewartview             30
# West Oscar              29
# West Dawnfurt           29
# Carrollfort             29
# Kelseyland              28
# New Andreamouth         28
# Lisaville               28
# New David               28
# East Erin               28
# Sarabury                27
# Sandymouth              27
# Kimberlychester         27
# Port Samantha           27
# Edwardsbury             27
# Smithhaven              27
# Alyssaberg              26
# Torresshire             26
# Spencertown             26
# Nguyenbury              26
# Davistown               25
#                         ..
# Jasonfort               12
# Clarkstad               12
# South Joseph            12
# ...

# %%
# Calculate total number of cities
total_cities = len(merge_table_df)
total_cities
# Out:
# 2407

# %%
fare_by_city = merge_table_df.groupby(['city','fare'])
sum_it_up = fare_by_city.sum()
sum_it_up
# Out:
#                       driver_count        ride_id
# city           fare
# Alvarezhaven   4.07             21  6100187302721
#                5.16             21  2233026076010
#                5.34             21  1108172306544
#                6.42             21  8394540350728
#                6.45             21  8939751998750
#                6.72             21  6152998520191
#                9.87             21  2747592323442
#                14.25            21  6431434271355
#                17.67            21  3829336915201
#                18.09            21  1197329964911
#                20.23            21  4348900295000
#                20.61            21  8307812366044
#                20.74            21   357421158941
#                20.88            21  9456788060940
#                22.54            21  6435260355302
#                22.83            21  3565582370530
#                24.16            21  9047320468692
# ...

# %%
unique_city = merge_table_df["city"].unique()
test = pd.DataFrame(unique_city).reset_index

test
# Out:
# <bound method DataFrame.reset_index of                         0
# 0              Kelseyland
# 1              Nguyenbury
# 2            East Douglas
# 3           West Dawnfurt
# 4          Rodriguezburgh
# 5       South Josephville
# 6        West Sydneyhaven
# 7             Travisville
# 8             Torresshire
# 9               Lisaville
# 10              Mooreview
# 11             Smithhaven
# 12            Carrollfort
# 13        Port Josephfurt
# 14       Lake Jeffreyland
# 15            South Louis
# 16             West Peter
# 17        Kimberlychester
# 18             Alyssaberg
# 19               Sarabury
# 20            Yolandafurt
# 21            Edwardsbury
# 22        New Andreamouth
# 23              New David
# 24             Arnoldview
# 25           Williamshire
# 26               Lisatown
# 27              New Aaron
# 28            Swansonbury
# 29             Fosterside
# ..                    ...
# 95            Conwaymouth
# 96               New Lynn
# ...

# %%
# Count how many times each maker appears in our group
count_cities = city['fare'].count()

count_cities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-4c40c86e212b> in <module>()
#       1 # Count how many times each maker appears in our group
# ----> 2 count_cities = city['fare'].count()
#       3
#       4 count_cities
#
# NameError: name 'city' is not defined

# %%
# Convert the "fare" column to numeric so the data can be used
merge_table['fare'] = pd.to_numeric(merge_table['fare'])

# %%
#sort by city and then by fare, so we can sum the dollar value of the fares.

fare = merge_table_df.groupby(['city','fare'])
sum_it_up = fare.sum()
sum_it_up
# Out:
#                       driver_count        ride_id
# city           fare
# Alvarezhaven   4.07             21  6100187302721
#                5.16             21  2233026076010
#                5.34             21  1108172306544
#                6.42             21  8394540350728
#                6.45             21  8939751998750
#                6.72             21  6152998520191
#                9.87             21  2747592323442
#                14.25            21  6431434271355
#                17.67            21  3829336915201
#                18.09            21  1197329964911
#                20.23            21  4348900295000
#                20.61            21  8307812366044
#                20.74            21   357421158941
#                20.88            21  9456788060940
#                22.54            21  6435260355302
#                22.83            21  3565582370530
#                24.16            21  9047320468692
# ...

# %%
reduced_df = sum_it_up[["ride_id"]]
reduced_df
# Out:
#                             ride_id
# city           fare
# Alvarezhaven   4.07   6100187302721
#                5.16   2233026076010
#                5.34   1108172306544
#                6.42   8394540350728
#                6.45   8939751998750
#                6.72   6152998520191
#                9.87   2747592323442
#                14.25  6431434271355
#                17.67  3829336915201
#                18.09  1197329964911
#                20.23  4348900295000
#                20.61  8307812366044
#                20.74   357421158941
#                20.88  9456788060940
#                22.54  6435260355302
#                22.83  3565582370530
#                24.16  9047320468692
#                27.51  6282665852239
#                31.08  7413831046469
#                31.74  5487020911007
#                31.82  7948246793429
#                31.93  4267015736324
#                32.46   858631473935
#                33.31   306054352684
# ...
